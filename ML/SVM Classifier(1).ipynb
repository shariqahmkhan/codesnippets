# %% [markdown]
# ### reading and understanding Images

# %%
# importing necessary modules
import numpy as np
from PIL import Image # to r|ead/process images
import os
from sklearn import svm, metrics
import cv2 as cv
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
base_dir = os.getcwd() + "\\dataset"
base_dir
# Out:
# 'C:\\Users\\Laptop\\KVCH\\dataset'

# %%
image_path = []
image_array = []
target = []
#classes = ["nd", "d1", "d2"]

# %%
for i in os.listdir(base_dir)[1:]: # only to ignore first .ipynb
    new_dir = base_dir + "\\{0}".format(i)
    print(new_dir)
    for j in os.listdir(new_dir):
        
        image_path.append(new_dir + "\\{0}".format(j)) # appending path to a list for dataset - important
        temp_var_img = cv.imread(new_dir + "\\{0}".format(j)) # intermediate temp variable to read image
        temp_var_img_gray = cv.cvtColor(temp_var_img, cv.COLOR_BGR2GRAY) # intermediate temp variable to convert to grayscale
        image_array.append(temp_var_img_gray)
        target.append(i)
# Out:
# C:\Users\Laptop\KVCH\dataset\d1
# C:\Users\Laptop\KVCH\dataset\d2
# C:\Users\Laptop\KVCH\dataset\nd

# %%
image_array.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-223-0c479e7553a7> in <module>
# ----> 1 image_array.shape
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
Image.fromarray(image_array[0])
# Out:
# <PIL.Image.Image image mode=L size=300x300 at 0x223A6ED78E0>

# %%
class_output = np.array(target)
class_output.shape
# Out:
# (218,)

# %%
# useful variables: image_path, image_array, target
image_array[0].shape
# Out:
# (300, 300)

# %%
len(image_array)
# Out:
# 218

# %%
concatenated_array = np.concatenate(image_array, axis=1) # converting list of array to array
n_samples = len(image_array)
data = concatenated_array.reshape((n_samples, -1)) # reshape

# %%
data.shape
# Out:
# (218, 90000)

# %%
# train SVC classifier
clf = svm.SVC(gamma=0.001) # IS HOW EFFECT OR WHAT IS THE INFLUENCE OF EACH DATA POINT - less = least strict bnoundary, more is more strict boundary

X_train, X_test, y_train, y_test = train_test_split(
    data,class_output, test_size=0.3, shuffle=True
)

# %%
y_train
# Out:
# array(['d2', 'd1', 'nd', 'd2', 'nd', 'd1', 'd1', 'd2', 'd2', 'd2', 'd2',
#        'nd', 'd2', 'd1', 'd1', 'd2', 'd2', 'nd', 'nd', 'nd', 'nd', 'd2',
#        'nd', 'd1', 'nd', 'nd', 'd2', 'nd', 'd2', 'd2', 'nd', 'd1', 'd2',
#        'd1', 'd1', 'd2', 'd1', 'd1', 'nd', 'nd', 'nd', 'nd', 'd1', 'd1',
#        'nd', 'd1', 'nd', 'd2', 'd1', 'nd', 'd1', 'd1', 'd2', 'nd', 'd1',
#        'd1', 'nd', 'd2', 'nd', 'd1', 'd1', 'nd', 'd1', 'd2', 'd2', 'nd',
#        'd1', 'd1', 'd2', 'd1', 'd2', 'd1', 'd1', 'nd', 'd2', 'nd', 'd2',
#        'nd', 'd1', 'nd', 'd1', 'nd', 'd1', 'nd', 'd2', 'nd', 'd1', 'd2',
#        'd2', 'nd', 'd1', 'd2', 'd2', 'nd', 'nd', 'd1', 'd1', 'nd', 'nd',
#        'nd', 'd1', 'nd', 'nd', 'nd', 'd1', 'd2', 'd2', 'nd', 'd2', 'nd',
#        'd1', 'd1', 'nd', 'nd', 'nd', 'nd', 'd1', 'd2', 'd1', 'd1', 'd1',
#        'd1', 'nd', 'd2', 'nd', 'd1', 'nd', 'd1', 'd1', 'd2', 'nd', 'd2',
#        'nd', 'd1', 'd2', 'd1', 'nd', 'nd', 'd1', 'nd', 'nd', 'd1', 'd2',
#        'nd', 'd1', 'nd', 'nd', 'd2', 'nd', 'nd', 'd1', 'nd'], dtype='<U2')

# %%
clf.fit(X_train, y_train)
# Out:
# SVC(gamma=0.001)

# %%
predicted = clf.predict(X_test)

# %%
X_test
# Out:
# array([[ 81,  80,  82, ...,  33,  23,   0],
#        [ 85,  84,  91, ..., 107,  84,  70],
#        [ 64,  60,  58, ..., 113,  91,  77],
#        ...,
#        [ 46,  46,  45, ..., 111,  98,  93],
#        [ 35,  33,  34, ...,  81,  81,  80],
#        [ 51,  52,  51, ...,  67,  66,  66]], dtype=uint8)

# %%
_, axes = plt.subplots(nrows=1, ncols=4, figsize=(10, 4))
for ax, image, prediction in zip(axes, X_test, predicted):
    ax.set_axis_off()
    image = image.reshape(300, 300)
    ax.imshow(image, cmap=plt.cm.gray_r, interpolation="nearest")
    ax.set_title(f"Prediction: {prediction}")

# %%
# flatten the images
n_samples = len(digits.images)
data = digits.images.reshape((n_samples, -1))

# %%
data.shape
# Out:
# (1797, 64)

# %%
data[1].shape
# Out:
# (64,)

# %%
digits.images
# Out:
# array([[[ 0.,  0.,  5., ...,  1.,  0.,  0.],
#         [ 0.,  0., 13., ..., 15.,  5.,  0.],
#         [ 0.,  3., 15., ..., 11.,  8.,  0.],
#         ...,
#         [ 0.,  4., 11., ..., 12.,  7.,  0.],
#         [ 0.,  2., 14., ..., 12.,  0.,  0.],
#         [ 0.,  0.,  6., ...,  0.,  0.,  0.]],
#
#        [[ 0.,  0.,  0., ...,  5.,  0.,  0.],
#         [ 0.,  0.,  0., ...,  9.,  0.,  0.],
#         [ 0.,  0.,  3., ...,  6.,  0.,  0.],
#         ...,
#         [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#         [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#         [ 0.,  0.,  0., ..., 10.,  0.,  0.]],
#
#        [[ 0.,  0.,  0., ..., 12.,  0.,  0.],
#         [ 0.,  0.,  3., ..., 14.,  0.,  0.],
#         [ 0.,  0.,  8., ..., 16.,  0.,  0.],
#         ...,
#         [ 0.,  9., 16., ...,  0.,  0.,  0.],
#         [ 0.,  3., 13., ..., 11.,  5.,  0.],
#         [ 0.,  0.,  0., ..., 16.,  9.,  0.]],
#
#        ...,
#
#        [[ 0.,  0.,  1., ...,  1.,  0.,  0.],
#         [ 0.,  0., 13., ...,  2.,  1.,  0.],
#         [ 0.,  0., 16., ..., 16.,  5.,  0.],
#         ...,
#         [ 0.,  0., 16., ..., 15.,  0.,  0.],
#         [ 0.,  0., 15., ..., 16.,  0.,  0.],
#         [ 0.,  0.,  2., ...,  6.,  0.,  0.]],
#
#        [[ 0.,  0.,  2., ...,  0.,  0.,  0.],
#         [ 0.,  0., 14., ..., 15.,  1.,  0.],
#         [ 0.,  4., 16., ..., 16.,  7.,  0.],
#         ...,
#         [ 0.,  0.,  0., ..., 16.,  2.,  0.],
#         [ 0.,  0.,  4., ..., 16.,  2.,  0.],
#         [ 0.,  0.,  5., ..., 12.,  0.,  0.]],
#
#        [[ 0.,  0., 10., ...,  1.,  0.,  0.],
#         [ 0.,  2., 16., ...,  1.,  0.,  0.],
#         [ 0.,  0., 15., ..., 15.,  0.,  0.],
#         ...,
#         [ 0.,  4., 16., ..., 16.,  6.,  0.],
#         [ 0.,  8., 16., ..., 16.,  8.,  0.],
#         [ 0.,  1.,  8., ..., 12.,  1.,  0.]]])
